# %% [markdown]
# <a href="https://colab.research.google.com/github/uquizxc456/NM/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 11
a
# Out:
# 11

# %%
b=22
print(a+b)
b
# Out:
# 33
# 22

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ![image.png](data:image/png;base64,...)
